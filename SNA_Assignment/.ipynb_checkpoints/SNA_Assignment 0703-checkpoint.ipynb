# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
import networkx as nx
plt.style.use('ggplot') 
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
edgesDF = pd.read_excel("MadridMetroDataset.xlsx",sheet_name='Edges' )

# %%
edgesDF.head()
# Out:
#    From   To Line  Weight
# 0   153  152    1   7.125
# 1   152  151    1   7.125
# 2   151  101    1   7.125
# 3   101  102    1   7.125
# 4   102  103    1   7.125

# %%
edgesDF.Line.unique()
# Out:
# array([1, 2, 3, 4, 5, 6, '7b', 7, 8, 9, '9b', '10b', 10, 11, 12, 'R'],
#       dtype=object)

# %%
nodesDF = pd.read_excel('MadridMetroDataset.xlsx',sheet_name='Nodes')
print(nodesDF.shape)
nodesDF.head()
# Out:
# (242, 14)
#    StationID          StationName  Entries  Utilization  NumberLines  \
# 0       1102             Abrantes   838992      1460425            1
# 1        519              Acacias  1411894      4098463            1
# 2        806  Aeropuerto T1-T2-T3  2879690      3738740            1
# 3        808        Aeropuerto T4  1758401      2913657            1
# 4        552     Alameda de Osuna  1336992      3110859            1
#
#     Latitude  Longitude           Coordinates  LatHour  LatMin  LatSec  \
# 0  40.381667  -3.726944  40°22′54″N 3°43′37″O       40      22      54
# 1  40.405000  -3.702778  40°24′18″N 3°42′10″O       40      24      18
# 2  40.468056  -3.570556  40°28′05″N 3°34′14″O       40      28       5
# 3  40.491389  -3.594167  40°29′29″N 3°35′39″O       40      29      29
# 4  40.456389  -3.587222  40°27′23″N 3°35′14″O       40      27      23
#
#    LonHour  LonMin  LonSec
# 0        3      43      37
# 1        3      42      10
# 2        3      34      14
# 3        3      35      39
# 4        3      35      14

# %%
nodesDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   StationID    242 non-null    int64
#  1   StationName  242 non-null    object
#  2   Entries      242 non-null    int64
#  3   Utilization  242 non-null    int64
#  4   NumberLines  242 non-null    int64
#  5   Latitude     242 non-null    float64
#  6   Longitude    242 non-null    float64
#  7   Coordinates  242 non-null    object
#  8   LatHour      242 non-null    int64
#  9   LatMin       242 non-null    int64
#  10  LatSec       242 non-null    int64
#  11  LonHour      242 non-null    int64
#  12  LonMin       242 non-null    int64
#  13  LonSec       242 non-null    int64
# dtypes: float64(2), int64(10), object(2)
# memory usage: 26.6+ KB

# %%
len(nodesDF.StationID.unique())
# Out:
# 242

# %%
weightDF = edgesDF[['Line','From','To','Weight']]
weightDF['Weight'] = weightDF['Weight']*1000
weightDF.head()
# Out:
#   Line  From   To  Weight
# 0    1   153  152  7125.0
# 1    1   152  151  7125.0
# 2    1   151  101  7125.0
# 3    1   101  102  7125.0
# 4    1   102  103  7125.0

# %%
weightDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Line    279 non-null    object
#  1   From    279 non-null    int64
#  2   To      279 non-null    int64
#  3   Weight  279 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 8.8+ KB

# %%
data = weightDF.loc[:,"From":].values.astype(int)
Madrid_tube = nx.Graph()
Madrid_tube.add_nodes_from(list(range(0,)))
Madrid_tube.add_weighted_edges_from(data,)

# %%
stationname_dict = {}
entries_dict = {}
utilization_dict = {}
numberlines_dict = {}
for key in nodesDF.StationID:
    stationname_dict[key] = nodesDF.loc[nodesDF.StationID == key,['StationName']].values[0][0]
    entries_dict[key]     = nodesDF.loc[nodesDF.StationID == key,['Entries']].values[0][0]
    utilization_dict[key] = nodesDF.loc[nodesDF.StationID == key,['Utilization']].values[0][0]
    numberlines_dict[key] = nodesDF.loc[nodesDF.StationID == key,['NumberLines']].values[0][0]
    
nx.set_node_attributes(Madrid_tube, stationname_dict, 'StationName')
nx.set_node_attributes(Madrid_tube, entries_dict, 'Entries')
nx.set_node_attributes(Madrid_tube, utilization_dict, 'Utilization')
nx.set_node_attributes(Madrid_tube, numberlines_dict, 'NumberLines')

# %%
# label_dict = {}
# for key in nodesDF.StationID:
#     item_dict = {}
#     item_dict['StationName'] = nodesDF.loc[nodesDF.StationID == key,['StationName']].values[0][0]
#     item_dict['Entries'] = nodesDF.loc[nodesDF.StationID == key,['Entries']].values[0][0]
#     item_dict['Utilization'] = nodesDF.loc[nodesDF.StationID == key,['Utilization']].values[0][0]
#     item_dict['NumberLines'] = nodesDF.loc[nodesDF.StationID == key,['NumberLines']].values[0][0]
#     label_dict[key] = item_dict
    
# nx.set_node_attributes(Madrid_tube, label_dict, 'labels')

# %%
graph_dict = dict(list(zip(['Madrid_tube'],
                      [Madrid_tube])))
for key in graph_dict:
    print(key)
    print(nx.info(graph_dict[key]))
    print()
# Out:
# Madrid_tube
# Name:
# Type: Graph
# Number of nodes: 242
# Number of edges: 276
# Average degree:   2.2810

# %%
## Paula

edgesDF['line_colour'] = edgesDF['Line'].replace('7b','7')
edgesDF['line_colour'] = edgesDF['line_colour'].replace('9b','9')
edgesDF['line_colour'] = edgesDF['line_colour'].replace('10b','10')
edgesDF['line_colour'] = edgesDF['line_colour'].replace('R','13')
edgesDF['line_colour'] = edgesDF['line_colour'].astype(int)
linesDF = edgesDF[['From','To','line_colour']]
data = linesDF.loc[:,"From":].values.astype(int)
Madrid_tube.add_weighted_edges_from(data,weight='line')
CR = [Madrid_tube[u][v]['line'] for u, v in Madrid_tube.edges]
color = np.where(np.asarray(CR) == 1,"#30a3dc", CR).tolist()
color = np.where(np.asarray(color) == '2',"#cd031d", color).tolist()
color = np.where(np.asarray(color) == '3',"#ffe114", color).tolist()
color = np.where(np.asarray(color) == '4',"#944248", color).tolist()
color = np.where(np.asarray(color) == '5',"#96bf0d", color).tolist()
color = np.where(np.asarray(color) == '6',"#a0a5a7", color).tolist()
color = np.where(np.asarray(color) == '7',"#faa64a", color).tolist()
color = np.where(np.asarray(color) == '8',"#f27ca2", color).tolist()
color = np.where(np.asarray(color) == '9',"#a93094", color).tolist()
color = np.where(np.asarray(color) == '10',"#084594", color).tolist()
color = np.where(np.asarray(color) == '11',"#008b43", color).tolist()
color = np.where(np.asarray(color) == '12',"#a49a00", color).tolist()
color = np.where(np.asarray(color) == '13',"#093163", color).tolist()
weights = [Madrid_tube[u][v]['weight'] for u,v in Madrid_tube.edges]

# entries = (nodesDF['Entries']/30000).values.tolist()
# exits = (abs(nodesDF['Entries']-nodesDF['Utilization'])/30000).values.tolist()
# utilization =  (nodesDF['Utilization']/30000).values.tolist()

entries = []
for number in [el[1] for el in list(Madrid_tube.nodes.data('Entries'))]:
    entries.append(number / 50000)

utilization = []
for number in [el[1] for el in list(Madrid_tube.nodes.data('Utilization'))]:
    utilization.append(number / 50000)
    
exits = (np.array(utilization) - np.array(entries)).tolist()

# %%
list(Madrid_tube.edges.data())
# Out:
# [(153, 152, {'weight': 7125, 'line': 1}),
#  (153, 422, {'weight': 4363, 'line': 4}),
#  (152, 151, {'weight': 7125, 'line': 1}),
#  (151, 101, {'weight': 9000, 'line': 10}),
#  (151, 1002, {'weight': 9000, 'line': 10}),
#  (101, 102, {'weight': 7125, 'line': 1}),
#  (101, 903, {'weight': 5217, 'line': 9}),
#  (101, 905, {'weight': 5217, 'line': 9}),
#  (101, 1005, {'weight': 9000, 'line': 10}),
#  (102, 103, {'weight': 7125, 'line': 1}),
#  (103, 104, {'weight': 7125, 'line': 1}),
#  (104, 105, {'weight': 7125, 'line': 1}),
#  (105, 106, {'weight': 7125, 'line': 1}),
#  (106, 107, {'weight': 7125, 'line': 1}),
#  (106, 214, {'weight': 3157, 'line': 2}),
#  (106, 618, {'weight': 6642, 'line': 6}),
#  (106, 620, {'weight': 6642, 'line': 6}),
#  (107, 108, {'weight': 7125, 'line': 1}),
#  (108, 109, {'weight': 7125, 'line': 1}),
#  (109, 110, {'weight': 7125, 'line': 1}),
#  (109, 212, {'weight': 4363, 'line': 4}),
#  (109, 404, {'weight': 4363, 'line': 4}),
#  (110, 111, {'weight': 7125, 'line': 1}),
#  (110, 404, {'weight': 9000, 'line': 10}),
#  (110, 308, {'weight': 9000, 'line': 10}),
#  (111, 112, {'weight': 7125, 'line': 1}),
#  (111, 513, {'weight': 6193, 'line': 5}),
#  (111, 307, {'weight': 6193, 'line': 5}),
#  (112, 113, {'weight': 7125, 'line': 1}),
#  (112, 207, {'weight': 3157, 'line': 2}),
#  (112, 209, {'weight': 3157, 'line': 2}),
#  (112, 305, {'weight': 9529, 'line': 3}),
#  (112, 307, {'weight': 9529, 'line': 3}),
#  (113, 114, {'weight': 7125, 'line': 1}),
#  (114, 115, {'weight': 7125, 'line': 1}),
#  (115, 116, {'weight': 7125, 'line': 1}),
#  (116, 117, {'weight': 7125, 'line': 1}),
#  (117, 118, {'weight': 7125, 'line': 1}),
#  (118, 119, {'weight': 7125, 'line': 1}),
#  (118, 609, {'weight': 6642, 'line': 6}),
#  (118, 611, {'weight': 6642, 'line': 6}),
#  (119, 120, {'weight': 7125, 'line': 1}),
#  (120, 121, {'weight': 7125, 'line': 1}),
#  (121, 122, {'weight': 7125, 'line': 1}),
#  (122, 123, {'weight': 7125, 'line': 1}),
#  (123, 124, {'weight': 7125, 'line': 1}),
#  (124, 125, {'weight': 7125, 'line': 1}),
#  (125, 126, {'weight': 7125, 'line': 1}),
#  (126, 127, {'weight': 7125, 'line': 1}),
#  (127, 128, {'weight': 7125, 'line': 1}),
#  (128, 129, {'weight': 7125, 'line': 1}),
#  (129, 130, {'weight': 7125, 'line': 1}),
#  (255, 254, {'weight': 3157, 'line': 2}),
#  (254, 253, {'weight': 3157, 'line': 2}),
#  (253, 252, {'weight': 3157, 'line': 2}),
#  (252, 251, {'weight': 3157, 'line': 2}),
#  (251, 201, {'weight': 3157, 'line': 2}),
#  (201, 202, {'weight': 3157, 'line': 2}),
#  (201, 507, {'weight': 6193, 'line': 5}),
#  (201, 410, {'weight': 6193, 'line': 5}),
#  (202, 203, {'weight': 3157, 'line': 2}),
#  (202, 613, {'weight': 6642, 'line': 6}),
#  (202, 410, {'weight': 6642, 'line': 6}),
#  (203, 204, {'weight': 3157, 'line': 2}),
#  (203, 407, {'weight': 4363, 'line': 4}),
#  (203, 409, {'weight': 4363, 'line': 4}),
#  (204, 205, {'weight': 3157, 'line': 2}),
#  (204, 510, {'weight': 5217, 'line': 9}),
#  (204, 913, {'weight': 5217, 'line': 9}),
#  (205, 206, {'weight': 3157, 'line': 2}),
#  (206, 207, {'weight': 3157, 'line': 2}),
#  (209, 210, {'weight': 3157, 'line': 2}),
#  (209, 307, {'weight': 6193, 'line': 5}),
#  (209, 517, {'weight': 6193, 'line': 5}),
#  (209, 625, {'weight': 8000, 'line': 13}),
#  (210, 211, {'weight': 3157, 'line': 2}),
#  (211, 212, {'weight': 3157, 'line': 2}),
#  (212, 213, {'weight': 3157, 'line': 2}),
#  (212, 310, {'weight': 4363, 'line': 4}),
#  (213, 214, {'weight': 3157, 'line': 2}),
#  (214, 712, {'weight': 4956, 'line': 7}),
#  (214, 714, {'weight': 4956, 'line': 7}),
#  (357, 356, {'weight': 9529, 'line': 3}),
#  (356, 355, {'weight': 9529, 'line': 3}),
#  (355, 354, {'weight': 9529, 'line': 3}),
#  (354, 353, {'weight': 9529, 'line': 3}),
#  (353, 352, {'weight': 9529, 'line': 3}),
#  (352, 351, {'weight': 9529, 'line': 3}),
#  (351, 301, {'weight': 9529, 'line': 3}),
#  (301, 302, {'weight': 9529, 'line': 3}),
#  (301, 606, {'weight': 6642, 'line': 6}),
#  (301, 608, {'weight': 6642, 'line': 6}),
#  (302, 303, {'weight': 9529, 'line': 3}),
#  (303, 304, {'weight': 9529, 'line': 3}),
#  (304, 305, {'weight': 9529, 'line': 3}),
#  (307, 308, {'weight': 9529, 'line': 3}),
#  (308, 309, {'weight': 9529, 'line': 3}),
#  (308, 625, {'weight': 9000, 'line': 10}),
#  (309, 310, {'weight': 9529, 'line': 3}),
#  (310, 311, {'weight': 6642, 'line': 6}),
#  (310, 625, {'weight': 6642, 'line': 6}),
#  (311, 622, {'weight': 6642, 'line': 6}),
#  (404, 405, {'weight': 4363, 'line': 4}),
#  (404, 511, {'weight': 6193, 'line': 5}),
#  (404, 513, {'weight': 6193, 'line': 5}),
#  (404, 711, {'weight': 9000, 'line': 10}),
#  (405, 406, {'weight': 4363, 'line': 4}),
#  (406, 407, {'weight': 4363, 'line': 4}),
#  (409, 410, {'weight': 4363, 'line': 4}),
#  (410, 411, {'weight': 6642, 'line': 6}),
#  (410, 510, {'weight': 6193, 'line': 5}),
#  (411, 412, {'weight': 4363, 'line': 4}),
#  (411, 617, {'weight': 6642, 'line': 6}),
#  (411, 709, {'weight': 4956, 'line': 7}),
#  (411, 711, {'weight': 4956, 'line': 7}),
#  (411, 909, {'weight': 5217, 'line': 9}),
#  (411, 510, {'weight': 5217, 'line': 9}),
#  (412, 413, {'weight': 4363, 'line': 4}),
#  (413, 414, {'weight': 4363, 'line': 4}),
#  (414, 415, {'weight': 4363, 'line': 4}),
#  (415, 416, {'weight': 4363, 'line': 4}),
#  (416, 417, {'weight': 4363, 'line': 4}),
#  (417, 418, {'weight': 4363, 'line': 4}),
#  (418, 419, {'weight': 4363, 'line': 4}),
#  (418, 803, {'weight': 6285, 'line': 8}),
#  (418, 805, {'weight': 6285, 'line': 8}),
#  (419, 420, {'weight': 4363, 'line': 4}),
#  (420, 421, {'weight': 4363, 'line': 4}),
#  (421, 422, {'weight': 4363, 'line': 4}),
#  (552, 551, {'weight': 6193, 'line': 5}),
#  (551, 501, {'weight': 6193, 'line': 5}),
#  (501, 502, {'weight': 6193, 'line': 5}),
#  (502, 503, {'weight': 6193, 'line': 5}),
#  (503, 504, {'weight': 6193, 'line': 5}),
#  (504, 505, {'weight': 6193, 'line': 5}),
#  (505, 506, {'weight': 6193, 'line': 5}),
#  (505, 705, {'weight': 4956, 'line': 7}),
#  (505, 707, {'weight': 4956, 'line': 7}),
#  (506, 507, {'weight': 6193, 'line': 5}),
#  (510, 511, {'weight': 6193, 'line': 5}),
#  (517, 518, {'weight': 6193, 'line': 5}),
#  (518, 519, {'weight': 6193, 'line': 5}),
#  (519, 520, {'weight': 6193, 'line': 5}),
#  (520, 521, {'weight': 6193, 'line': 5}),
#  (521, 522, {'weight': 6193, 'line': 5}),
#  (522, 523, {'weight': 6193, 'line': 5}),
#  (523, 524, {'weight': 6193, 'line': 5}),
#  (523, 602, {'weight': 6642, 'line': 6}),
#  (523, 604, {'weight': 6642, 'line': 6}),
#  (524, 525, {'weight': 6193, 'line': 5}),
#  (525, 526, {'weight': 6193, 'line': 5}),
#  (526, 527, {'weight': 6193, 'line': 5}),
#  (527, 528, {'weight': 6193, 'line': 5}),
#  (528, 529, {'weight': 6193, 'line': 5}),
#  (529, 530, {'weight': 6193, 'line': 5}),
#  (530, 1014, {'weight': 9000, 'line': 10}),
#  (530, 1016, {'weight': 9000, 'line': 10}),
#  (601, 602, {'weight': 6642, 'line': 6}),
#  (601, 628, {'weight': 6642, 'line': 6}),
#  (604, 605, {'weight': 6642, 'line': 6}),
#  (605, 606, {'weight': 6642, 'line': 6}),
#  (605, 1102, {'weight': 3500, 'line': 11}),
#  (608, 609, {'weight': 6642, 'line': 6}),
#  (611, 612, {'weight': 6642, 'line': 6}),
#  (612, 613, {'weight': 6642, 'line': 6}),
#  (612, 913, {'weight': 5217, 'line': 9}),
#  (612, 915, {'weight': 5217, 'line': 9}),
#  (617, 618, {'weight': 6642, 'line': 6}),
#  (618, 802, {'weight': 6285, 'line': 8}),
#  (618, 1006, {'weight': 9000, 'line': 10}),
#  (618, 711, {'weight': 9000, 'line': 10}),
#  (620, 621, {'weight': 6642, 'line': 6}),
#  (620, 714, {'weight': 4956, 'line': 7}),
#  (620, 716, {'weight': 4956, 'line': 7}),
#  (621, 622, {'weight': 6642, 'line': 6}),
#  (625, 626, {'weight': 6642, 'line': 6}),
#  (625, 1013, {'weight': 9000, 'line': 10}),
#  (626, 627, {'weight': 6642, 'line': 6}),
#  (627, 628, {'weight': 6642, 'line': 6}),
#  (760, 759, {'weight': 2571, 'line': 7}),
#  (759, 758, {'weight': 2571, 'line': 7}),
#  (758, 757, {'weight': 2571, 'line': 7}),
#  (757, 756, {'weight': 2571, 'line': 7}),
#  (756, 755, {'weight': 2571, 'line': 7}),
#  (755, 754, {'weight': 2571, 'line': 7}),
#  (754, 751, {'weight': 2571, 'line': 7}),
#  (751, 701, {'weight': 4956, 'line': 7}),
#  (701, 702, {'weight': 4956, 'line': 7}),
#  (702, 703, {'weight': 4956, 'line': 7}),
#  (703, 704, {'weight': 4956, 'line': 7}),
#  (704, 705, {'weight': 4956, 'line': 7}),
#  (707, 708, {'weight': 4956, 'line': 7}),
#  (708, 709, {'weight': 4956, 'line': 7}),
#  (711, 712, {'weight': 4956, 'line': 7}),
#  (716, 717, {'weight': 4956, 'line': 7}),
#  (717, 718, {'weight': 4956, 'line': 7}),
#  (718, 719, {'weight': 4956, 'line': 7}),
#  (719, 720, {'weight': 4956, 'line': 7}),
#  (720, 721, {'weight': 4956, 'line': 7}),
#  (721, 722, {'weight': 4956, 'line': 7}),
#  (722, 723, {'weight': 4956, 'line': 7}),
#  (802, 803, {'weight': 6285, 'line': 8}),
#  (802, 906, {'weight': 5217, 'line': 9}),
#  (802, 908, {'weight': 5217, 'line': 9}),
#  (805, 806, {'weight': 6285, 'line': 8}),
#  (806, 807, {'weight': 6285, 'line': 8}),
#  (807, 808, {'weight': 6285, 'line': 8}),
#  (952, 951, {'weight': 5217, 'line': 9}),
#  (951, 901, {'weight': 5217, 'line': 9}),
#  (901, 902, {'weight': 5217, 'line': 9}),
#  (902, 903, {'weight': 5217, 'line': 9}),
#  (905, 906, {'weight': 5217, 'line': 9}),
#  (908, 909, {'weight': 5217, 'line': 9}),
#  (915, 916, {'weight': 5217, 'line': 9}),
#  (916, 917, {'weight': 5217, 'line': 9}),
#  (917, 918, {'weight': 5217, 'line': 9}),
#  (918, 919, {'weight': 5217, 'line': 9}),
#  (919, 920, {'weight': 5217, 'line': 9}),
#  (920, 921, {'weight': 5217, 'line': 9}),
#  (921, 922, {'weight': 5217, 'line': 9}),
#  (922, 923, {'weight': 3500, 'line': 9}),
#  (923, 924, {'weight': 3500, 'line': 9}),
#  (924, 925, {'weight': 3500, 'line': 9}),
#  (925, 926, {'weight': 3500, 'line': 9}),
#  (926, 927, {'weight': 3500, 'line': 9}),
#  (1061, 1060, {'weight': 3300, 'line': 10}),
#  (1060, 1059, {'weight': 3300, 'line': 10}),
#  (1059, 1058, {'weight': 3300, 'line': 10}),
#  (1058, 1057, {'weight': 3300, 'line': 10}),
#  (1057, 1056, {'weight': 3300, 'line': 10}),
#  (1056, 1055, {'weight': 3300, 'line': 10}),
#  (1055, 1054, {'weight': 3300, 'line': 10}),
#  (1054, 1053, {'weight': 3300, 'line': 10}),
#  (1053, 1052, {'weight': 3300, 'line': 10}),
#  (1052, 1051, {'weight': 3300, 'line': 10}),
#  (1051, 1001, {'weight': 9000, 'line': 10}),
#  (1001, 1002, {'weight': 9000, 'line': 10}),
#  (1005, 1006, {'weight': 9000, 'line': 10}),
#  (1013, 1014, {'weight': 9000, 'line': 10}),
#  (1016, 1018, {'weight': 9000, 'line': 10}),
#  (1018, 1019, {'weight': 9000, 'line': 10}),
#  (1019, 1020, {'weight': 9000, 'line': 10}),
#  (1020, 1021, {'weight': 9000, 'line': 10}),
#  (1021, 1202, {'weight': 2357, 'line': 12}),
#  (1021, 1230, {'weight': 2357, 'line': 12}),
#  (1102, 1103, {'weight': 3500, 'line': 11}),
#  (1103, 1104, {'weight': 3500, 'line': 11}),
#  (1104, 1105, {'weight': 3500, 'line': 11}),
#  (1105, 1106, {'weight': 3500, 'line': 11}),
#  (1106, 1107, {'weight': 3500, 'line': 11}),
#  (1202, 1203, {'weight': 2357, 'line': 12}),
#  (1203, 1204, {'weight': 2357, 'line': 12}),
#  (1204, 1205, {'weight': 2357, 'line': 12}),
#  (1205, 1206, {'weight': 2357, 'line': 12}),
#  (1206, 1207, {'weight': 2357, 'line': 12}),
#  (1207, 1208, {'weight': 2357, 'line': 12}),
#  (1208, 1209, {'weight': 2357, 'line': 12}),
#  (1209, 1210, {'weight': 2357, 'line': 12}),
#  (1210, 1212, {'weight': 2357, 'line': 12}),
#  (1212, 1213, {'weight': 2357, 'line': 12}),
#  (1213, 1214, {'weight': 2357, 'line': 12}),
#  (1214, 1215, {'weight': 2357, 'line': 12}),
#  (1215, 1217, {'weight': 2357, 'line': 12}),
#  (1217, 1218, {'weight': 2357, 'line': 12}),
#  (1218, 1219, {'weight': 2357, 'line': 12}),
#  (1219, 1220, {'weight': 2357, 'line': 12}),
#  (1220, 1221, {'weight': 2357, 'line': 12}),
#  (1221, 1222, {'weight': 2357, 'line': 12}),
#  (1222, 1223, {'weight': 2357, 'line': 12}),
#  (1223, 1224, {'weight': 2357, 'line': 12}),
#  (1224, 1225, {'weight': 2357, 'line': 12}),
#  (1225, 1226, {'weight': 2357, 'line': 12}),
#  (1226, 1227, {'weight': 2357, 'line': 12}),
#  (1227, 1228, {'weight': 2357, 'line': 12}),
#  (1228, 1229, {'weight': 2357, 'line': 12}),
#  (1229, 1230, {'weight': 2357, 'line': 12})]

# %%
fig, ax = plt.subplots(nrows=3
                       ,figsize=(20,20))
nx.draw(Madrid_tube
        ,edge_cmap= cm.get_cmap('spring')
        ,ax=ax[0]
        ,node_size=entries)

nx.draw(Madrid_tube
        ,edge_cmap= cm.get_cmap('summer')
        ,ax=ax[1]
        ,node_size=exits)

nx.draw(Madrid_tube
        ,edge_cmap= cm.get_cmap('inferno')
        ,ax=ax[2]
        ,node_size=utilization)

# %%
pos_dict = {}
for key in nodesDF.StationID:
    pos_dict[key] = list(nodesDF.loc[nodesDF.StationID == key,['Longitude','Latitude']].values[0])

# %%
#station names
Stationlabels=dict((n,d['StationName']) for n,d in Madrid_tube.nodes(data=True))

# %%
# plt.figure(figsize=(30,30))
# nx.draw(Madrid_tube,pos=pos_dict,node_size=20,edge_color=color_lines,node_color='r',alpha=0.8)
# plt.show()

plt.figure(figsize=(30,23))
nx.draw(Madrid_tube,pos=pos_dict,node_size=,edge_color=color,node_color='r'
        ,width=weights,alpha=0.8,labels=Stationlabels)
plt.show()
# Out:
#   File "<ipython-input-225-ec19527b8858>", line 6
#     nx.draw(Madrid_tube,pos=pos_dict,node_size=,edge_color=color,node_color='r'
#                                                ^
# SyntaxError: invalid syntax

# %%
# plt.figure(figsize=(30,30))
# nx.draw(Madrid_tube,pos=pos_dict,node_size=20,edge_color=color_lines,node_color='r',alpha=0.8)
# plt.show()

# plt.figure(figsize=(30,23))
# nx.draw(Madrid_tube,pos=pos_dict,node_size=exits,edge_color=color,node_color='g',
#         width=(np.array(weights)/1000).tolist(),alpha=0.8,labels=Stationlabels)
# plt.show()

plt.figure(figsize=(30,23))
nx.draw(Madrid_tube,pos=pos_dict,node_size=entries,edge_color=color,node_color='g',
        width=(np.array(weights)/1000).tolist(),alpha=0.8)
plt.show()

# %%
#!pip install mplleaflet
# Out:
# Collecting mplleaflet
#   Downloading mplleaflet-0.0.5.tar.gz (37 kB)
# Requirement already satisfied: jinja2 in /anaconda3/lib/python3.7/site-packages (from mplleaflet) (2.11.1)
# Requirement already satisfied: six in /anaconda3/lib/python3.7/site-packages (from mplleaflet) (1.14.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda3/lib/python3.7/site-packages (from jinja2->mplleaflet) (1.1.1)
# Building wheels for collected packages: mplleaflet
#   Building wheel for mplleaflet (setup.py) ... done
#   Created wheel for mplleaflet: filename=mplleaflet-0.0.5-py3-none-any.whl size=28554 sha256=156fdf8168204497d72123e849d1453f380dc78777574cfee553a73592a94eb9
#   Stored in directory: /Users/paula/Library/Caches/pip/wheels/6b/f5/21/cdd12e476182b4b0b98326cdb9efa02ddbd5d87ca5de051c84
# Successfully built mplleaflet
# Installing collected packages: mplleaflet
# Successfully installed mplleaflet-0.0.5

# %%
#dic = Madrid_tube.edge_attr_dict_factory

# %%
# plt.figure(figsize=(30,23))
# nx.draw(Madrid_tube,pos=pos_dict,node_size=exits,edge_color=color,node_color='g',width=weights,alpha=0.8
#         ,labels=Stationlabels)
# plt.show()
# -----------


import mplleaflet



pos = pos_dict
labels = Stationlabels


fig, ax = plt.subplots(figsize=(10,10))
plt.style.use(['dark_background'])

nx.draw(Madrid_tube,pos=pos_dict,node_size=entries,edge_color=color,node_color='b',alpha=0.9
        ,width=(np.array(weights)/1500).tolist()
#        ,labels=Stationlabels
       )

mplleaflet.display(fig=fig)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src="data:text/html;base64,..." width="100%" height="600"></iframe>

# %%
from collections import Counter
c = Counter(Madrid_tube.edges())  # Contains frequencies of each directed edge.

for u, v, d in Madrid_tube.edges(data=True):
    d['weight'] = c[u, v]


    
weights = [d['weight'] for _, _, d in Madrid_tube.edges(data=True)]    
weights
# Out:
# [{'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 1},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 13},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 2},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 3},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 8},
#  {'weight': {...}, 'line': 8},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 4},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 5},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 11},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 8},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 6},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 7},
#  {'weight': {...}, 'line': 8},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 8},
#  {'weight': {...}, 'line': 8},
#  {'weight': {...}, 'line': 8},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 9},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 10},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 11},
#  {'weight': {...}, 'line': 11},
#  {'weight': {...}, 'line': 11},
#  {'weight': {...}, 'line': 11},
#  {'weight': {...}, 'line': 11},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12},
#  {'weight': {...}, 'line': 12, 0: {...}}]

# %%
import mplleaflet

fig, ax = plt.subplots()

nx.draw_networkx_nodes(Madrid_tube,pos=pos_dict,node_size=exits,node_color='red',edge_color='k',alpha=.5
                       , with_labels=True,labels=Stationlabels)
nx.draw_networkx_edges(Madrid_tube,pos=pos_dict,edge_color=color, alpha=.1,width=weights)
nx.draw_networkx_labels(Madrid_tube,pos_dict, label_pos =10.3)

mplleaflet.display(fig=ax.figure)







# plt.figure(figsize=(30,23))
# nx.draw(Madrid_tube,pos=pos_dict,node_size=exits,edge_color=color,node_color='g',width=weights,alpha=0.8
#         ,labels=Stationlabels)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, **kwds)
#     396     try:
# --> 397         xy = np.asarray([pos[v] for v in nodelist])
#     398     except KeyError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py in <listcomp>(.0)
#     396     try:
# --> 397         xy = np.asarray([pos[v] for v in nodelist])
#     398     except KeyError as e:
#
# KeyError: 153
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-148-6dac9a922dc0> in <module>
#       4
#       5 nx.draw_networkx_nodes(Madrid_tube,pos=pos_dict,node_size=exits,node_color='red',edge_color='k',alpha=.5
# ----> 6                        , with_labels=True,labels=Stationlabels)
#       7 nx.draw_networkx_edges(Madrid_tube,pos=pos_dict,edge_color=color, alpha=.1,width=weights)
#       8 nx.draw_networkx_labels(Madrid_tube,pos_dict, label_pos =10.3)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, **kwds)
#     397         xy = np.asarray([pos[v] for v in nodelist])
#     398     except KeyError as e:
# --> 399         raise nx.NetworkXError('Node %s has no position.' % e)
#     400     except ValueError:
#     401         raise nx.NetworkXError('Bad value in node positions.')
#
# NetworkXError: Node 153 has no position.

# %%
Madrid_tube.nodes(data=True)
# Out:
# NodeDataView({153: {'labels': {'StationName': 'Pinar de Chamartín', 'Entries': 4101034, 'Utilization': 11709050, 'NumberLines': 2}}, 152: {'labels': {'StationName': 'Bambú', 'Entries': 1159127, 'Utilization': 2413194, 'NumberLines': 1}}, 151: {'labels': {'StationName': 'Chamartín', 'Entries': 6426557, 'Utilization': 14738349, 'NumberLines': 2}}, 101: {'labels': {'StationName': 'Plaza de Castilla', 'Entries': 13279507, 'Utilization': 37361848, 'NumberLines': 3}}, 102: {'labels': {'StationName': 'Valdeacederas', 'Entries': 2711332, 'Utilization': 5038540, 'NumberLines': 1}}, 103: {'labels': {'StationName': 'Tetuán', 'Entries': 3511657, 'Utilization': 6895295, 'NumberLines': 1}}, 104: {'labels': {'StationName': 'Estrecho', 'Entries': 5072727, 'Utilization': 9203377, 'NumberLines': 1}}, 105: {'labels': {'StationName': 'Alvarado', 'Entries': 2031672, 'Utilization': 3463184, 'NumberLines': 1}}, 106: {'labels': {'StationName': 'Cuatro Caminos', 'Entries': 7056088, 'Utilization': 23402733, 'NumberLines': 3}}, 107: {'labels': {'StationName': 'Ríos Rosas', 'Entries': 2311575, 'Utilization': 5112119, 'NumberLines': 1}}, 108: {'labels': {'StationName': 'Iglesia', 'Entries': 3483146, 'Utilization': 7365867, 'NumberLines': 1}}, 109: {'labels': {'StationName': 'Bilbao', 'Entries': 4730963, 'Utilization': 14211880, 'NumberLines': 1}}, 110: {'labels': {'StationName': 'Tribunal', 'Entries': 5566961, 'Utilization': 18381200, 'NumberLines': 2}}, 111: {'labels': {'StationName': 'Gran Vía', 'Entries': 4347621, 'Utilization': 12932430, 'NumberLines': 2}}, 112: {'labels': {'StationName': 'Sol', 'Entries': 23720463, 'Utilization': 70953620, 'NumberLines': 3}}, 113: {'labels': {'StationName': 'Tirso de Molina', 'Entries': 3878698, 'Utilization': 7355345, 'NumberLines': 1}}, 114: {'labels': {'StationName': 'Antón Martín', 'Entries': 2875079, 'Utilization': 6012548, 'NumberLines': 1}}, 115: {'labels': {'StationName': 'Estación del Arte', 'Entries': 2731321, 'Utilization': 8041817, 'NumberLines': 1}}, 116: {'labels': {'StationName': 'Atocha-Renfe', 'Entries': 8875459, 'Utilization': 14368554, 'NumberLines': 1}}, 117: {'labels': {'StationName': 'Menéndez Pelayo', 'Entries': 2232223, 'Utilization': 4032576, 'NumberLines': 1}}, 118: {'labels': {'StationName': 'Pacífico', 'Entries': 4920430, 'Utilization': 21551142, 'NumberLines': 2}}, 119: {'labels': {'StationName': 'Puente de Vallecas', 'Entries': 3952263, 'Utilization': 7363578, 'NumberLines': 1}}, 120: {'labels': {'StationName': 'Nueva Numancia', 'Entries': 3903270, 'Utilization': 6494085, 'NumberLines': 1}}, 121: {'labels': {'StationName': 'Portazgo', 'Entries': 2273332, 'Utilization': 4403176, 'NumberLines': 1}}, 122: {'labels': {'StationName': 'Buenos Aires', 'Entries': 1613771, 'Utilization': 4632126, 'NumberLines': 1}}, 123: {'labels': {'StationName': 'Alto del Arenal', 'Entries': 1972942, 'Utilization': 3526000, 'NumberLines': 1}}, 124: {'labels': {'StationName': 'Miguel Hernández', 'Entries': 2244087, 'Utilization': 3959067, 'NumberLines': 1}}, 125: {'labels': {'StationName': 'Sierra de Guadalupe', 'Entries': 2504105, 'Utilization': 4253628, 'NumberLines': 1}}, 126: {'labels': {'StationName': 'Villa de Vallecas', 'Entries': 1681942, 'Utilization': 3104603, 'NumberLines': 1}}, 127: {'labels': {'StationName': 'Congosto', 'Entries': 1376779, 'Utilization': 2570718, 'NumberLines': 1}}, 128: {'labels': {'StationName': 'La Gavia', 'Entries': 1071314, 'Utilization': 2304395, 'NumberLines': 1}}, 129: {'labels': {'StationName': 'Las Suertes', 'Entries': 1842217, 'Utilization': 3183938, 'NumberLines': 1}}, 130: {'labels': {'StationName': 'Valdecarros', 'Entries': 736633, 'Utilization': 1536049, 'NumberLines': 1}}, 255: {'labels': {'StationName': 'Las Rosas', 'Entries': 1216664, 'Utilization': 2965189, 'NumberLines': 1}}, 254: {'labels': {'StationName': 'Avenida de Guadalajara', 'Entries': 1189368, 'Utilization': 2129440, 'NumberLines': 1}}, 253: {'labels': {'StationName': 'Alsacia', 'Entries': 1740837, 'Util ...

# %%
diameter = nx.diameter(Madrid_tube)
print(nx.diameter(Madrid_tube))
# Out:
# 44

# %% [markdown]
# **How to get the shortest path between two stations?**

# %%
def find_shortest_path(Graph,df,FromStation,ToStation):
    nodecheck = 1
    try:
        start_node = int(df.StationID[df.StationName==FromStation])
    except:
        print('Your start point does not exist.')
        nodecheck = 0
    try:
        end_node = int(df.StationID[df.StationName==ToStation])
    except:
        print('Your start point does not exist.')
        nodecheck = 0
    if nodecheck == 1:
        try:
            pathlength = nx.shortest_path_length(Graph, start_node, end_node)
            path = nx.shortest_path(Graph, start_node, end_node)
            print("The shortest path from {} to {} crosses".format(FromStation,ToStation), end=' ') 
            print((', ').join(list(df.StationName[[path]])[1:-1])+".")
            print("The path length is", str(pathlength)+'.')
            print("You will have to take the following lines:")
            connection = list(df.StationId[nx.shortest_path(Graph, start_node, end_node)])
            lines = []
            for i in range(len(connection)-1):
                conn = list(weightDF.Line[((weightDF.From==connection[i]) & (weightDF.To==connection[i+1])) |
                        ((weightDF.From==connection[i+1]) & (weightDF.To==connection[i]))])
                if len(conn)>1:
                    conn = (' or ').join(conn)
                else: 
                    conn = conn[0]
                if conn not in lines:
                    lines.append(conn)
            print((', ').join(lines))
        except:
            print("There is no path between {} and {}.".format(FromStation,ToStation))

# %%
find_shortest_path(Madrid_tube,nodesDF,'Nuevos Ministerios','Avenida de América')
# Out:
# The shortest path from Nuevos Ministerios to Avenida de América crosses There is no path between Nuevos Ministerios and Avenida de América.

# %%
FromStation = 'Las Rosas'
ToStation = 'Avenida de América'

start_node = int(nodesDF.StationID[nodesDF.StationName==FromStation])
end_node = int(nodesDF.StationID[nodesDF.StationName==ToStation])
print(start_node,end_node)
# Out:
# 255 411

# %%
nx.shortest_path_length(Madrid_tube, start_node, end_node)
# Out:
# 7

# %%
path = nx.shortest_path(Madrid_tube, start_node, end_node)
print(path)
# Out:
# [255, 254, 253, 252, 251, 201, 410, 411]

# %%
nodesDF.index = nodesDF['StationID']

# %%
print((', ').join(list(nodesDF.StationName[path])[1:-1])+".")
# Out:
# Avenida de Guadalajara, Alsacia, La Almudena, La Elipa, Ventas, Diego de León.

# %%
connection = list(nodesDF.StationID[nx.shortest_path(Madrid_tube, start_node, end_node)])
connection
# Out:
# [255, 254, 253, 252, 251, 201, 410, 411]

# %%
range(len(connection)-1)
# Out:
# range(0, 7)

# %%
list(weightDF.Line[((weightDF.From==connection[0]) & (weightDF.To==connection[1])) |
                        ((weightDF.From==connection[1]) & (weightDF.To==connection[0]))])
# Out:
# [2]

# %%
connection[0]
# Out:
# 255

# %%
nodesDF.StationName[connection[0]]
# Out:
# 'Las Rosas'

# %%
weightDF.head(1)
# Out:
#   Line  From   To  Weight
# 0    1   153  152  7125.0

# %%
colors = ['blue']
plt.hist([list(dict(nx.degree(Madrid_tube)).values())],
         bins=np.linspace(0,8,9)+0.5,alpha=1,stacked=False,color=colors,label=colors)
plt.yscale('log')
plt.legend(['Madrid Tube'],prop={'size': 10})
plt.title('Degree distributions')
plt.show()

# %%
nodesDF['betweenness_centrality'] = list(nx.betweenness_centrality(Madrid_tube).values())

# %%
plt.figure(figsize=(15,10))
plt.barh(list(range(20)),nodesDF.sort_values(by='betweenness_centrality',ascending=False)
         .head(20).betweenness_centrality)
plt.yticks(list(range(20)),nodesDF.sort_values(by='betweenness_centrality',ascending=False).head(20).StationName)
plt.show()

# %%
nodesDF['closeness_centrality'] = list(nx.closeness_centrality(Madrid_tube).values())

# %%
plt.figure(figsize=(15,10))
plt.barh(list(range(20)),nodesDF.sort_values(by='closeness_centrality',ascending=False)
         .head(20).closeness_centrality)
plt.yticks(list(range(20)),nodesDF.sort_values(by='closeness_centrality',ascending=False).head(20).StationName)
plt.show()

# %%
#Eigenvector Centrality
nodesDF['eigenvector_centrality'] = list(nx.eigenvector_centrality_numpy(Madrid_tube).values())

# %%
plt.figure(figsize=(15,10))
plt.barh(list(range(20)),nodesDF.sort_values(by='eigenvector_centrality',ascending=False)
         .head(20).eigenvector_centrality)
plt.yticks(list(range(20)),nodesDF.sort_values(by='eigenvector_centrality',ascending=False).head(20).StationName)
plt.show()

# %%
#Average shortest path length
nx.average_shortest_path_length(Madrid_tube)
# Out:
# 14.583690545591715

# %%
#Clusterting coefficient

nx.transitivity(Madrid_tube)
# Out:
# 0.03325942350332594

# %%
 nx.all_shortest_paths
# Out:
# <function networkx.algorithms.shortest_paths.generic.all_shortest_paths(G, source, target, weight=None, method='dijkstra')>

# %%
nx.is_weighted(Madrid_tube)
nx.is_directed(Madrid_tube)
# Out:
# False

# %%
Madrid_tube.edges()
# Out:
# EdgeView([(153, 152), (153, 422), (152, 151), (151, 101), (151, 1002), (101, 102), (101, 903), (101, 905), (101, 1005), (102, 103), (103, 104), (104, 105), (105, 106), (106, 107), (106, 214), (106, 618), (106, 620), (107, 108), (108, 109), (109, 110), (109, 212), (109, 404), (110, 111), (110, 404), (110, 308), (111, 112), (111, 513), (111, 307), (112, 113), (112, 207), (112, 209), (112, 305), (112, 307), (113, 114), (114, 115), (115, 116), (116, 117), (117, 118), (118, 119), (118, 609), (118, 611), (119, 120), (120, 121), (121, 122), (122, 123), (123, 124), (124, 125), (125, 126), (126, 127), (127, 128), (128, 129), (129, 130), (255, 254), (254, 253), (253, 252), (252, 251), (251, 201), (201, 202), (201, 507), (201, 410), (202, 203), (202, 613), (202, 410), (203, 204), (203, 407), (203, 409), (204, 205), (204, 510), (204, 913), (205, 206), (206, 207), (209, 210), (209, 307), (209, 517), (209, 625), (210, 211), (211, 212), (212, 213), (212, 310), (213, 214), (214, 712), (214, 714), (357, 356), (356, 355), (355, 354), (354, 353), (353, 352), (352, 351), (351, 301), (301, 302), (301, 606), (301, 608), (302, 303), (303, 304), (304, 305), (307, 308), (308, 309), (308, 625), (309, 310), (310, 311), (310, 625), (311, 622), (404, 405), (404, 511), (404, 513), (404, 711), (405, 406), (406, 407), (409, 410), (410, 411), (410, 510), (411, 412), (411, 617), (411, 709), (411, 711), (411, 909), (411, 510), (412, 413), (413, 414), (414, 415), (415, 416), (416, 417), (417, 418), (418, 419), (418, 803), (418, 805), (419, 420), (420, 421), (421, 422), (552, 551), (551, 501), (501, 502), (502, 503), (503, 504), (504, 505), (505, 506), (505, 705), (505, 707), (506, 507), (510, 511), (517, 518), (518, 519), (519, 520), (520, 521), (521, 522), (522, 523), (523, 524), (523, 602), (523, 604), (524, 525), (525, 526), (526, 527), (527, 528), (528, 529), (529, 530), (530, 1014), (530, 1016), (601, 602), (601, 628), (604, 605), (605, 606), (605, 1102), (608, 609), (611, 612), (612, 613), (612, 913), (612, 915), (617, 618), (618, 802), (618, 1006), (618, 711), (620, 621), (620, 714), (620, 716), (621, 622), (625, 626), (625, 1013), (626, 627), (627, 628), (760, 759), (759, 758), (758, 757), (757, 756), (756, 755), (755, 754), (754, 751), (751, 701), (701, 702), (702, 703), (703, 704), (704, 705), (707, 708), (708, 709), (711, 712), (716, 717), (717, 718), (718, 719), (719, 720), (720, 721), (721, 722), (722, 723), (802, 803), (802, 906), (802, 908), (805, 806), (806, 807), (807, 808), (952, 951), (951, 901), (901, 902), (902, 903), (905, 906), (908, 909), (915, 916), (916, 917), (917, 918), (918, 919), (919, 920), (920, 921), (921, 922), (922, 923), (923, 924), (924, 925), (925, 926), (926, 927), (1061, 1060), (1060, 1059), (1059, 1058), (1058, 1057), (1057, 1056), (1056, 1055), (1055, 1054), (1054, 1053), (1053, 1052), (1052, 1051), (1051, 1001), (1001, 1002), (1005, 1006), (1013, 1014), (1016, 1018), (1018, 1019), (1019, 1020), (1020, 1021), (1021, 1202), (1021, 1230), (1102, 1103), (1103, 1104), (1104, 1105), (1105, 1106), (1106, 1107), (1202, 1203), (1203, 1204), (1204, 1205), (1205, 1206), (1206, 1207), (1207, 1208), (1208, 1209), (1209, 1210), (1210, 1212), (1212, 1213), (1213, 1214), (1214, 1215), (1215, 1217), (1217, 1218), (1218, 1219), (1219, 1220), (1220, 1221), (1221, 1222), (1222, 1223), (1223, 1224), (1224, 1225), (1225, 1226), (1226, 1227), (1227, 1228), (1228, 1229), (1229, 1230)])

# %%
Madrid_tube.get_edge_data(1228,1229)
# Out:
# {'weight': 2357, 'line': 12}

# %%
weightDF[weightDF['From'] == 1228].head()
# Out:
#     Line  From    To       Weight
# 275   12  1228  1229  2357.142857
